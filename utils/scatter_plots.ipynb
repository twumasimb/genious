# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
cols=["cola", "mrpc", "rte", "stsb", "sst2", "mnli-m", "mnli-mm", "qnli", "qqp","avg","time"]

# %%
regular_bert_250K=[50.93,90.57,66.26,88.89,91.21,82.73,83.15,90.17,87.56,81.27444444,70861]
regular_bert_375K=[52.9,90.25,66.59,89.08,91.03,83.09,83.52,90.73,87.7,81.65444444,106196]
regular_bert_500K=[55.01,90.31,69.06,88.93,91.79,83.37,83.73,90.92,87.77,82.32111111,141503]
tfidf_sampling_250K=[52.19,89.89,67.5,88.5,91.37,82.36,82.75,89.85,87.49,81.32222222,80494]
tfidf_sampling_375K=[54.35,90.92,67.6,88.86,91.46,82.98,83.35,90.56,87.62,81.96666667,119342]
tfidf_sampling_500K=[54.47,90.36,68.03,88.85,92.14,83.21,83.9,90.83,87.75,82.17111111,158135]
layer9_sampling_250K=[54.61,89.68,67.16,88.94,91.13,82.07,82.81,90.4,87.57,81.59666667,96338]
layer9_sampling_375K=[55.61,90.49,69.03,89.12,91.21,82.56,83.17,90.47,87.65,82.14555556,135199]
layer9_sampling_500K=[55.92,90.41,69.49,88.79,91.64,83.09,83.59,90.9,87.84,82.40777778,174053]
regular_bert_1M=[]

# %%
task="avg"
idx=cols.index(task)
x1=[regular_bert_250K[-1],regular_bert_375K[-1], regular_bert_500K[-1]]
y1=[regular_bert_250K[idx], regular_bert_375K[idx], regular_bert_500K[idx]]
plt.plot(x1, y1, marker="x")
x2=[tfidf_sampling_250K[-1], tfidf_sampling_375K[-1], tfidf_sampling_500K[-1]]
y2=[tfidf_sampling_250K[idx], tfidf_sampling_375K[idx], tfidf_sampling_500K[idx]]
plt.plot(x2, y2, marker="x")
x3=[layer9_sampling_250K[-1], layer9_sampling_375K[-1], layer9_sampling_500K[-1]]
y3=[layer9_sampling_250K[idx], layer9_sampling_375K[idx], layer9_sampling_500K[idx]]
plt.plot(x3, y3, marker="x")
plt.legend(["regular bert", "tfidf+sampling", "layer9+sampling"])

# %%
task="cola"
idx=cols.index(task)
x1=[regular_bert_250K[-1],regular_bert_375K[-1], regular_bert_500K[-1]]
y1=[regular_bert_250K[idx], regular_bert_375K[idx], regular_bert_500K[idx]]
plt.plot(x1, y1, marker="x")
x2=[tfidf_sampling_250K[-1], tfidf_sampling_375K[-1], tfidf_sampling_500K[-1]]
y2=[tfidf_sampling_250K[idx], tfidf_sampling_375K[idx], tfidf_sampling_500K[idx]]
plt.plot(x2, y2, marker="x")
x3=[layer9_sampling_250K[-1], layer9_sampling_375K[-1], layer9_sampling_500K[-1]]
y3=[layer9_sampling_250K[idx], layer9_sampling_375K[idx], layer9_sampling_500K[idx]]
plt.plot(x3, y3, marker="x")
plt.legend(["regular bert", "tfidf+sampling", "layer9+sampling"])

# %%
task="cola"
idx=cols.index(task)
x=[250, 375, 500]
y1=[regular_bert_250K[idx], regular_bert_375K[idx], regular_bert_500K[idx]]
plt.plot(x, y1, marker="x")
y2=[tfidf_sampling_250K[idx], tfidf_sampling_375K[idx], tfidf_sampling_500K[idx]]
plt.plot(x, y2, marker="x")
y3=[layer9_sampling_250K[idx], layer9_sampling_375K[idx], layer9_sampling_500K[idx]]
plt.plot(x, y3, marker="x")
plt.legend(["regular bert", "tfidf+sampling", "layer9+sampling"])

# %%
task="avg"
idx=cols.index(task)
x=[250, 375, 500]
y1=[regular_bert_250K[idx], regular_bert_375K[idx], regular_bert_500K[idx]]
plt.plot(x, y1, marker="x")
y2=[tfidf_sampling_250K[idx], tfidf_sampling_375K[idx], tfidf_sampling_500K[idx]]
plt.plot(x, y2, marker="x")
y3=[layer9_sampling_250K[idx], layer9_sampling_375K[idx], layer9_sampling_500K[idx]]
plt.plot(x, y3, marker="x")
plt.legend(["regular bert", "tfidf+sampling", "layer9+sampling"])
